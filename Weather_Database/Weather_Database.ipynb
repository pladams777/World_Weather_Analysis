# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | poopo
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 1 | beeville
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | ushtobe
# Processing Record 12 of Set 1 | urucara
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | nautanwa
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | steinbach
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | maraa
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | nalut
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | sabang
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | turbat
# Processing Record 37 of Set 1 | najran
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | tombouctou
# Processing Record 41 of Set 1 | beringovskiy
# Processing Record 42 of Set 1 | mpika
# Processing Record 43 of Set 1 | alekseyevka
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | katsuura
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | san cristobal
# Processing Record 3 of Set 2 | waingapu
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | tarko-sale
# Processing Record 6 of Set 2 | rio gallegos
# Processing Record 7 of Set 2 | sakakah
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | pyay
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | minatitlan
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | kozhva
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | ossora
# Processing Record 19 of Set 2 | coolum beach
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | marquette
# Processing Record 22 of Set 2 | cap malheureux
# Processing Record 23 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 2 | daru
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 2 | keskin
# Processing Record 28 of Set 2 | kosa
# Processing Record 29 of Set 2 | san andres
# Processing Record 30 of Set 2 | awbari
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | la peca
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | gizo
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | bermeo
# Processing Record 41 of Set 2 | mosquera
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | sorland
# Processing Record 44 of Set 2 | alice springs
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | dongsheng
# Processing Record 47 of Set 2 | sao filipe
# Processing Record 48 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 2 | benalla
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | severo-kurilsk
# Processing Record 2 of Set 3 | likasi
# Processing Record 3 of Set 3 | kuala terengganu
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | gushikawa
# Processing Record 7 of Set 3 | nouadhibou
# Processing Record 8 of Set 3 | rocha
# Processing Record 9 of Set 3 | rikitea
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | chikwawa
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | broome
# Processing Record 15 of Set 3 | srednekolymsk
# Processing Record 16 of Set 3 | umba
# Processing Record 17 of Set 3 | oyem
# Processing Record 18 of Set 3 | boyuibe
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | arlit
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | tvedestrand
# Processing Record 24 of Set 3 | urdoma
# Processing Record 25 of Set 3 | lianzhou
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 3 | mpanda
# Processing Record 29 of Set 3 | port hardy
# Processing Record 30 of Set 3 | talcahuano
# Processing Record 31 of Set 3 | kirakira
# Processing Record 32 of Set 3 | dongying
# Processing Record 33 of Set 3 | zheshart
# Processing Record 34 of Set 3 | naron
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | acarau
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | simao
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | dunedin
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | olafsvik
# Processing Record 50 of Set 3 | charcas
# Processing Record 1 of Set 4 | binga
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | saint-joseph
# Processing Record 4 of Set 4 | punta arenas
# Processing Record 5 of Set 4 | maragogi
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | sur
# Processing Record 8 of Set 4 | del rio
# Processing Record 9 of Set 4 | vestmanna
# Processing Record 10 of Set 4 | rawson
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | revda
# Processing Record 14 of Set 4 | nerja
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | haines junction
# Processing Record 17 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | jamestown
# Processing Record 22 of Set 4 | sumenep
# Processing Record 23 of Set 4 | hapur
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | whithorn
# Processing Record 27 of Set 4 | gander
# Processing Record 28 of Set 4 | ano mera
# Processing Record 29 of Set 4 | greenville
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | farafangana
# Processing Record 32 of Set 4 | grande prairie
# Processing Record 33 of Set 4 | fort-shevchenko
# Processing Record 34 of Set 4 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 4 | tomatlan
# Processing Record 36 of Set 4 | lompoc
# Processing Record 37 of Set 4 | aswan
# Processing Record 38 of Set 4 | barpeta
# Processing Record 39 of Set 4 | san luis
# Processing Record 40 of Set 4 | yialos
# City not found. Skipping...
# Processing Record 41 of Set 4 | progreso
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | dongkan
# Processing Record 45 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | pandan
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | sunndalsora
# Processing Record 50 of Set 4 | kushmurun
# Processing Record 1 of Set 5 | homer
# Processing Record 2 of Set 5 | hobyo
# Processing Record 3 of Set 5 | shasta lake
# Processing Record 4 of Set 5 | sampit
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | arani
# Processing Record 7 of Set 5 | pompeia
# Processing Record 8 of Set 5 | iquique
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | rundu
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | chicaman
# Processing Record 13 of Set 5 | qaanaaq
# Processing Record 14 of Set 5 | danane
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | port elizabeth
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | concordia
# Processing Record 19 of Set 5 | port blair
# Processing Record 20 of Set 5 | karasjok
# Processing Record 21 of Set 5 | port-gentil
# Processing Record 22 of Set 5 | santiago del estero
# Processing Record 23 of Set 5 | uray
# Processing Record 24 of Set 5 | shache
# Processing Record 25 of Set 5 | rafraf
# Processing Record 26 of Set 5 | belyy
# Processing Record 27 of Set 5 | tocopilla
# Processing Record 28 of Set 5 | aberdeen
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | ushumun
# Processing Record 31 of Set 5 | townsville
# Processing Record 32 of Set 5 | torbat-e jam
# Processing Record 33 of Set 5 | flinders
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | aitape
# Processing Record 36 of Set 5 | chancay
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | winnemucca
# Processing Record 41 of Set 5 | uglekamensk
# Processing Record 42 of Set 5 | bowen
# Processing Record 43 of Set 5 | bud
# Processing Record 44 of Set 5 | kyaiklat
# Processing Record 45 of Set 5 | vung tau
# Processing Record 46 of Set 5 | micheweni
# Processing Record 47 of Set 5 | dalvik
# Processing Record 48 of Set 5 | surgut
# Processing Record 49 of Set 5 | beyneu
# Processing Record 50 of Set 5 | kokopo
# Processing Record 1 of Set 6 | jalu
# Processing Record 2 of Set 6 | yangliuqing
# Processing Record 3 of Set 6 | urumqi
# Processing Record 4 of Set 6 | muroto
# Processing Record 5 of Set 6 | tiksi
# Processing Record 6 of Set 6 | la rioja
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | nicoya
# Processing Record 10 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 6 | adrar
# Processing Record 12 of Set 6 | kaeo
# Processing Record 13 of Set 6 | atikokan
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | hovd
# Processing Record 16 of Set 6 | tessalit
# Processing Record 17 of Set 6 | russell
# Processing Record 18 of Set 6 | shelburne
# Processing Record 19 of Set 6 | mazsalaca
# Processing Record 20 of Set 6 | sisimiut
# Processing Record 21 of Set 6 | puro
# Processing Record 22 of Set 6 | yerbogachen
# Processing Record 23 of Set 6 | amapa
# Processing Record 24 of Set 6 | siderno
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | grenaa
# Processing Record 27 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 28 of Set 6 | kismayo
# Processing Record 29 of Set 6 | vanimo
# Processing Record 30 of Set 6 | aranjuez
# Processing Record 31 of Set 6 | miandrivazo
# Processing Record 32 of Set 6 | alakurtti
# Processing Record 33 of Set 6 | kenai
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | san quintin
# Processing Record 37 of Set 6 | pelym
# Processing Record 38 of Set 6 | sao miguel do araguaia
# Processing Record 39 of Set 6 | rabo de peixe
# Processing Record 40 of Set 6 | huarmey
# Processing Record 41 of Set 6 | dumabato
# Processing Record 42 of Set 6 | jadu
# Processing Record 43 of Set 6 | bana
# Processing Record 44 of Set 6 | belaya gora
# Processing Record 45 of Set 6 | lata
# Processing Record 46 of Set 6 | chernyshevskiy
# Processing Record 47 of Set 6 | kalmunai
# Processing Record 48 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 6 | santo antonio do ica
# Processing Record 50 of Set 6 | miri
# Processing Record 1 of Set 7 | kifri
# Processing Record 2 of Set 7 | bilma
# Processing Record 3 of Set 7 | ahipara
# Processing Record 4 of Set 7 | plainview
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | sudova vyshnya
# Processing Record 7 of Set 7 | brae
# Processing Record 8 of Set 7 | imperia
# Processing Record 9 of Set 7 | dargaville
# Processing Record 10 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 11 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | vallenar
# Processing Record 13 of Set 7 | nhulunbuy
# Processing Record 14 of Set 7 | grand-lahou
# Processing Record 15 of Set 7 | opuwo
# Processing Record 16 of Set 7 | hirara
# Processing Record 17 of Set 7 | mayo
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | carsamba
# Processing Record 20 of Set 7 | beloha
# Processing Record 21 of Set 7 | karoi
# Processing Record 22 of Set 7 | el wasta
# City not found. Skipping...
# Processing Record 23 of Set 7 | thinadhoo
# Processing Record 24 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 7 | baykit
# Processing Record 26 of Set 7 | cholet
# Processing Record 27 of Set 7 | tayu
# Processing Record 28 of Set 7 | moen
# Processing Record 29 of Set 7 | jumla
# Processing Record 30 of Set 7 | mapimi
# Processing Record 31 of Set 7 | yuanping
# Processing Record 32 of Set 7 | vao
# Processing Record 33 of Set 7 | riyadh
# Processing Record 34 of Set 7 | tiarei
# Processing Record 35 of Set 7 | buchanan
# Processing Record 36 of Set 7 | westport
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | muros
# Processing Record 39 of Set 7 | gukovo
# Processing Record 40 of Set 7 | oranjemund
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | meulaboh
# Processing Record 43 of Set 7 | atar
# Processing Record 44 of Set 7 | svetlyy
# Processing Record 45 of Set 7 | izberbash
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | port augusta
# Processing Record 48 of Set 7 | kostivere
# Processing Record 49 of Set 7 | codajas
# Processing Record 50 of Set 7 | slavyanka
# Processing Record 1 of Set 8 | korla
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | ruthin
# Processing Record 4 of Set 8 | killybegs
# Processing Record 5 of Set 8 | novoagansk
# Processing Record 6 of Set 8 | mokhsogollokh
# Processing Record 7 of Set 8 | mehamn
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | garowe
# Processing Record 10 of Set 8 | novyy urgal
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | lakhdenpokhya
# Processing Record 13 of Set 8 | thompson
# Processing Record 14 of Set 8 | klaksvik
# Processing Record 15 of Set 8 | puerto madryn
# Processing Record 16 of Set 8 | manali
# Processing Record 17 of Set 8 | abnub
# Processing Record 18 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 8 | san juan
# Processing Record 20 of Set 8 | duz
# City not found. Skipping...
# Processing Record 21 of Set 8 | asau
# Processing Record 22 of Set 8 | oksfjord
# Processing Record 23 of Set 8 | fairbanks
# Processing Record 24 of Set 8 | tabat
# Processing Record 25 of Set 8 | kulhudhuffushi
# Processing Record 26 of Set 8 | valenca do piaui
# Processing Record 27 of Set 8 | catia la mar
# Processing Record 28 of Set 8 | williams lake
# Processing Record 29 of Set 8 | constitucion
# Processing Record 30 of Set 8 | madisonville
# Processing Record 31 of Set 8 | berlevag
# Processing Record 32 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 8 | vydrino
# Processing Record 34 of Set 8 | pignon
# Processing Record 35 of Set 8 | tiznit
# Processing Record 36 of Set 8 | banamba
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 8 | mabaruma
# Processing Record 39 of Set 8 | roros
# Processing Record 40 of Set 8 | araouane
# Processing Record 41 of Set 8 | tasiilaq
# Processing Record 42 of Set 8 | prestea
# Processing Record 43 of Set 8 | calbuco
# Processing Record 44 of Set 8 | gnjilane
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | kilmez
# City not found. Skipping...
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | pauini
# Processing Record 49 of Set 8 | tarauaca
# Processing Record 50 of Set 8 | mount gambier
# Processing Record 1 of Set 9 | wamba
# Processing Record 2 of Set 9 | hami
# Processing Record 3 of Set 9 | baruun-urt
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | kirkwood
# Processing Record 6 of Set 9 | puerto salgar
# Processing Record 7 of Set 9 | fernie
# Processing Record 8 of Set 9 | lorengau
# Processing Record 9 of Set 9 | sambava
# Processing Record 10 of Set 9 | mataram
# Processing Record 11 of Set 9 | laguna
# Processing Record 12 of Set 9 | guanica
# Processing Record 13 of Set 9 | inhambane
# Processing Record 14 of Set 9 | dakar
# Processing Record 15 of Set 9 | swellendam
# Processing Record 16 of Set 9 | vila franca do campo
# Processing Record 17 of Set 9 | the valley
# Processing Record 18 of Set 9 | burnie
# Processing Record 19 of Set 9 | manggar
# Processing Record 20 of Set 9 | barranca
# Processing Record 21 of Set 9 | ferme-neuve
# Processing Record 22 of Set 9 | morondava
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | manado
# Processing Record 25 of Set 9 | port macquarie
# Processing Record 26 of Set 9 | puerto escondido
# Processing Record 27 of Set 9 | pacifica
# Processing Record 28 of Set 9 | desna
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | marinhais
# Processing Record 31 of Set 9 | iseyin
# Processing Record 32 of Set 9 | kargasok
# Processing Record 33 of Set 9 | changde
# Processing Record 34 of Set 9 | faridabad
# Processing Record 35 of Set 9 | khani
# Processing Record 36 of Set 9 | angoche
# Processing Record 37 of Set 9 | bumba
# Processing Record 38 of Set 9 | chumikan
# Processing Record 39 of Set 9 | penzance
# Processing Record 40 of Set 9 | ulaangom
# Processing Record 41 of Set 9 | vasilyevskiy mokh
# Processing Record 42 of Set 9 | dawei
# Processing Record 43 of Set 9 | koumac
# Processing Record 44 of Set 9 | bolshaya rechka
# Processing Record 45 of Set 9 | amga
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | dhidhdhoo
# Processing Record 48 of Set 9 | wilmington
# Processing Record 49 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 9 | antalaha
# Processing Record 1 of Set 10 | itarema
# Processing Record 2 of Set 10 | ketchikan
# Processing Record 3 of Set 10 | juniyah
# City not found. Skipping...
# Processing Record 4 of Set 10 | moorhead
# Processing Record 5 of Set 10 | bukama
# Processing Record 6 of Set 10 | kieta
# Processing Record 7 of Set 10 | svetlogorsk
# Processing Record 8 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 10 | thyolo
# Processing Record 10 of Set 10 | conceicao do araguaia
# Processing Record 11 of Set 10 | pacific grove
# Processing Record 12 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 10 | ucluelet
# Processing Record 14 of Set 10 | fortuna
# Processing Record 15 of Set 10 | nyurba
# Processing Record 16 of Set 10 | tateyama
# Processing Record 17 of Set 10 | ternate
# Processing Record 18 of Set 10 | moron
# Processing Record 19 of Set 10 | oistins
# Processing Record 20 of Set 10 | bassila
# Processing Record 21 of Set 10 | pitsunda
# Processing Record 22 of Set 10 | saint-pierre
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | lappeenranta
# Processing Record 25 of Set 10 | ust-ishim
# Processing Record 26 of Set 10 | altamira
# Processing Record 27 of Set 10 | linhai
# Processing Record 28 of Set 10 | deputatskiy
# Processing Record 29 of Set 10 | wadi musa
# Processing Record 30 of Set 10 | alta
# Processing Record 31 of Set 10 | patterson
# Processing Record 32 of Set 10 | kahului
# Processing Record 33 of Set 10 | lao cai
# Processing Record 34 of Set 10 | berberati
# Processing Record 35 of Set 10 | yatou
# Processing Record 36 of Set 10 | trairi
# Processing Record 37 of Set 10 | vila velha
# Processing Record 38 of Set 10 | wakkanai
# Processing Record 39 of Set 10 | harnosand
# Processing Record 40 of Set 10 | sohag
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | requena
# Processing Record 43 of Set 10 | margate
# Processing Record 44 of Set 10 | isangel
# Processing Record 45 of Set 10 | port moresby
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | ahuimanu
# Processing Record 48 of Set 10 | zyryanka
# Processing Record 49 of Set 10 | maibong
# Processing Record 50 of Set 10 | baie-comeau
# Processing Record 1 of Set 11 | kolosovka
# Processing Record 2 of Set 11 | poso
# Processing Record 3 of Set 11 | naze
# Processing Record 4 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | carauari
# Processing Record 6 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 11 | ventspils
# Processing Record 8 of Set 11 | taoudenni
# Processing Record 9 of Set 11 | kayerkan
# Processing Record 10 of Set 11 | malaryta
# Processing Record 11 of Set 11 | itaituba
# Processing Record 12 of Set 11 | hofn
# Processing Record 13 of Set 11 | borzya
# Processing Record 14 of Set 11 | puerto carreno
# Processing Record 15 of Set 11 | shenjiamen
# Processing Record 16 of Set 11 | normandin
# Processing Record 17 of Set 11 | ordynskoye
# Processing Record 18 of Set 11 | alyangula
# Processing Record 19 of Set 11 | havoysund
# Processing Record 20 of Set 11 | yueyang
# Processing Record 21 of Set 11 | toowoomba
# Processing Record 22 of Set 11 | carutapera
# Processing Record 23 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 11 | aden
# Processing Record 25 of Set 11 | christchurch
# Processing Record 26 of Set 11 | kloulklubed
# Processing Record 27 of Set 11 | staryy nadym
# Processing Record 28 of Set 11 | mawlaik
# Processing Record 29 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 11 | haimen
# Processing Record 31 of Set 11 | lagoa
# Processing Record 32 of Set 11 | talakan
# Processing Record 33 of Set 11 | hlotse
# Processing Record 34 of Set 11 | catuday
# Processing Record 35 of Set 11 | sobolevo
# Processing Record 36 of Set 11 | koslan
# Processing Record 37 of Set 11 | aykhal
# Processing Record 38 of Set 11 | shingu
# Processing Record 39 of Set 11 | hit
# Processing Record 40 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 11 | mingaora
# Processing Record 42 of Set 11 | grindavik
# Processing Record 43 of Set 11 | yate
# Processing Record 44 of Set 11 | huayucachi
# Processing Record 45 of Set 11 | sitka
# Processing Record 46 of Set 11 | hornepayne
# Processing Record 47 of Set 11 | amiens
# Processing Record 48 of Set 11 | merrill
# Processing Record 49 of Set 11 | banda aceh
# Processing Record 50 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 12 | santa engracia
# Processing Record 2 of Set 12 | vagur
# Processing Record 3 of Set 12 | culebra
# Processing Record 4 of Set 12 | caldas da rainha
# Processing Record 5 of Set 12 | popondetta
# Processing Record 6 of Set 12 | marzuq
# Processing Record 7 of Set 12 | palmer
# Processing Record 8 of Set 12 | zabol
# Processing Record 9 of Set 12 | puerto guzman
# Processing Record 10 of Set 12 | khandbari
# Processing Record 11 of Set 12 | coihaique
# Processing Record 12 of Set 12 | mizan teferi
# Processing Record 13 of Set 12 | portland
# Processing Record 14 of Set 12 | saint-marc
# Processing Record 15 of Set 12 | pangnirtung
# Processing Record 16 of Set 12 | mutoko
# Processing Record 17 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 18 of Set 12 | iralaya
# Processing Record 19 of Set 12 | xixiang
# Processing Record 20 of Set 12 | soe
# Processing Record 21 of Set 12 | kazachinskoye
# Processing Record 22 of Set 12 | peace river
# Processing Record 23 of Set 12 | sawakin
# Processing Record 24 of Set 12 | igrim
# Processing Record 25 of Set 12 | ussel
# Processing Record 26 of Set 12 | naryan-mar
# Processing Record 27 of Set 12 | abeche
# Processing Record 28 of Set 12 | totness
# Processing Record 29 of Set 12 | kiunga
# Processing Record 30 of Set 12 | roma
# Processing Record 31 of Set 12 | ust-nera
# Processing Record 32 of Set 12 | nantucket
# Processing Record 33 of Set 12 | olinda
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | herat
# Processing Record 36 of Set 12 | sinnamary
# Processing Record 37 of Set 12 | mogadishu
# Processing Record 38 of Set 12 | mandali
# Processing Record 39 of Set 12 | yorkton
# Processing Record 40 of Set 12 | paducah
# Processing Record 41 of Set 12 | santa marta
# Processing Record 42 of Set 12 | monrovia
# Processing Record 43 of Set 12 | riwaka
# Processing Record 44 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 45 of Set 12 | eureka
# Processing Record 46 of Set 12 | fort nelson
# Processing Record 47 of Set 12 | ochsenfurt
# Processing Record 48 of Set 12 | uyuni
# Processing Record 49 of Set 12 | saint-augustin
# Processing Record 50 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 13 | mahanoro
# Processing Record 2 of Set 13 | shimoda
# Processing Record 3 of Set 13 | sola
# Processing Record 4 of Set 13 | isla vista
# Processing Record 5 of Set 13 | buala
# Processing Record 6 of Set 13 | dudinka
# Processing Record 7 of Set 13 | umm kaddadah
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | mishelevka
# Processing Record 10 of Set 13 | moranbah
# Processing Record 11 of Set 13 | mookane
# Processing Record 12 of Set 13 | muzhi
# Processing Record 13 of Set 13 | kununurra
# Processing Record 14 of Set 13 | oktyabrskoye
# Processing Record 15 of Set 13 | ampanihy
# Processing Record 16 of Set 13 | galesong
# Processing Record 17 of Set 13 | assiniboia
# Processing Record 18 of Set 13 | deep river
# Processing Record 19 of Set 13 | goderich
# Processing Record 20 of Set 13 | newport
# Processing Record 21 of Set 13 | antofagasta
# Processing Record 22 of Set 13 | george town
# Processing Record 23 of Set 13 | pedernales
# Processing Record 24 of Set 13 | comodoro rivadavia
# Processing Record 25 of Set 13 | sucua
# Processing Record 26 of Set 13 | lerwick
# Processing Record 27 of Set 13 | shu
# Processing Record 28 of Set 13 | lufilufi
# Processing Record 29 of Set 13 | obsharovka
# Processing Record 30 of Set 13 | walla walla
# Processing Record 31 of Set 13 | athabasca
# Processing Record 32 of Set 13 | paramaribo
# Processing Record 33 of Set 13 | surt
# Processing Record 34 of Set 13 | tura
# Processing Record 35 of Set 13 | kuna
# Processing Record 36 of Set 13 | mandalgovi
# Processing Record 37 of Set 13 | viedma
# Processing Record 38 of Set 13 | ambilobe
# Processing Record 39 of Set 13 | prince rupert
# Processing Record 40 of Set 13 | tuy hoa
# Processing Record 41 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 13 | ankpa
# Processing Record 43 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 44 of Set 13 | maxixe
# Processing Record 45 of Set 13 | plettenberg bay
# Processing Record 46 of Set 13 | ruteng
# Processing Record 47 of Set 13 | san jose
# Processing Record 48 of Set 13 | morant bay
# Processing Record 49 of Set 13 | maceio
# Processing Record 50 of Set 13 | romitan
# Processing Record 1 of Set 14 | bayangol
# Processing Record 2 of Set 14 | zhuhai
# Processing Record 3 of Set 14 | corsicana
# Processing Record 4 of Set 14 | alexandria
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 14 | shangzhi
# Processing Record 8 of Set 14 | porto novo
# Processing Record 9 of Set 14 | paramonga
# Processing Record 10 of Set 14 | nelson bay
# Processing Record 11 of Set 14 | stornoway
# Processing Record 12 of Set 14 | buarcos
# Processing Record 13 of Set 14 | wesselsbron
# Processing Record 14 of Set 14 | avera
# Processing Record 15 of Set 14 | chaupal
# Processing Record 16 of Set 14 | nambiyur
# Processing Record 17 of Set 14 | santa cruz
# Processing Record 18 of Set 14 | smirnykh
# Processing Record 19 of Set 14 | udachnyy
# Processing Record 20 of Set 14 | soldatskiy
# City not found. Skipping...
# Processing Record 21 of Set 14 | sandwick
# Processing Record 22 of Set 14 | yambio
# Processing Record 23 of Set 14 | praia da vitoria
# Processing Record 24 of Set 14 | lasa
# Processing Record 25 of Set 14 | fierze
# City not found. Skipping...
# Processing Record 26 of Set 14 | torit
# Processing Record 27 of Set 14 | wahiawa
# Processing Record 28 of Set 14 | rio grande
# Processing Record 29 of Set 14 | parambu
# Processing Record 30 of Set 14 | wucheng
# Processing Record 31 of Set 14 | baglung
# Processing Record 32 of Set 14 | yerani
# City not found. Skipping...
# Processing Record 33 of Set 14 | beira
# Processing Record 34 of Set 14 | aguilas
# Processing Record 35 of Set 14 | gunjur
# Processing Record 36 of Set 14 | gimli
# Processing Record 37 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 14 | burns lake
# Processing Record 39 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 14 | leshukonskoye
# Processing Record 41 of Set 14 | sulphur
# Processing Record 42 of Set 14 | avanigadda
# Processing Record 43 of Set 14 | puerto maldonado
# Processing Record 44 of Set 14 | gedo
# Processing Record 45 of Set 14 | vadso
# Processing Record 46 of Set 14 | kudahuvadhoo
# Processing Record 47 of Set 14 | manokwari
# Processing Record 48 of Set 14 | la ronge
# Processing Record 49 of Set 14 | akwatia
# Processing Record 50 of Set 14 | udarnyy
# Processing Record 1 of Set 15 | grand gaube
# Processing Record 2 of Set 15 | suntar
# Processing Record 3 of Set 15 | bugama
# Processing Record 4 of Set 15 | azar shahr
# City not found. Skipping...
# Processing Record 5 of Set 15 | boysun
# Processing Record 6 of Set 15 | sterling
# Processing Record 7 of Set 15 | iracoubo
# Processing Record 8 of Set 15 | tarnogskiy gorodok
# Processing Record 9 of Set 15 | sorong
# Processing Record 10 of Set 15 | kiama
# Processing Record 11 of Set 15 | babayurt
# Processing Record 12 of Set 15 | kaduna
# Processing Record 13 of Set 15 | mazatlan
# Processing Record 14 of Set 15 | sharjah
# Processing Record 15 of Set 15 | raton
# Processing Record 16 of Set 15 | keti bandar
# Processing Record 17 of Set 15 | pangai
# Processing Record 18 of Set 15 | bozdar
# Processing Record 19 of Set 15 | warrnambool
# Processing Record 20 of Set 15 | nova olimpia
# Processing Record 21 of Set 15 | kapit
# Processing Record 22 of Set 15 | orhei
# Processing Record 23 of Set 15 | stillwater
# Processing Record 24 of Set 15 | tinjah
# City not found. Skipping...
# Processing Record 25 of Set 15 | permet
# Processing Record 26 of Set 15 | hualmay
# Processing Record 27 of Set 15 | pucallpa
# Processing Record 28 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 15 | yaan
# Processing Record 30 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 15 | pareora
# Processing Record 32 of Set 15 | xapuri
# Processing Record 33 of Set 15 | waipawa
# Processing Record 34 of Set 15 | coracora
# Processing Record 35 of Set 15 | morgan city
# Processing Record 36 of Set 15 | bentiu
# Processing Record 37 of Set 15 | naliya
# Processing Record 38 of Set 15 | bataipora
# Processing Record 39 of Set 15 | zalantun
# Processing Record 40 of Set 15 | izhma
# Processing Record 41 of Set 15 | abu samrah
# Processing Record 42 of Set 15 | okhotsk
# Processing Record 43 of Set 15 | te anau
# Processing Record 44 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 15 | urengoy
# Processing Record 46 of Set 15 | erenhot
# Processing Record 47 of Set 15 | walvis bay
# Processing Record 48 of Set 15 | itacoatiara
# Processing Record 49 of Set 15 | tirumakudal narsipur
# Processing Record 50 of Set 15 | nemuro
# Processing Record 1 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 16 | namatanai
# Processing Record 3 of Set 16 | edendale
# Processing Record 4 of Set 16 | krasnogorskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini -21.2000 -175.2000     76.50        73         100
# 1          Poopo -18.3667  -66.9667     66.45         5           0
# 2       Beeville  28.4008  -97.7483     50.63        50         100
# 3       Bengkulu  -3.8004  102.2655     74.19        90          98
# 4         Narsaq  60.9167  -46.0500     26.82        81         100
# 5     Butaritari   3.0707  172.7902     80.35        79          15
# 6       Cherskiy  68.7500  161.3000    -13.59        98         100
# 7  Leningradskiy  69.3833  178.4167    -24.61        97          13
# 8        Ushtobe  45.2514   77.9838     43.97        85         100
# 9        Urucara  -2.5364  -57.7600    102.65        23          18
#
#    Wind Speed Country Weather Description
# 0        6.44      TO     overcast clouds
# 1       14.58      BO           clear sky
# 2        4.61      US     overcast clouds
# 3        5.06      ID     overcast clouds
# 4        1.03      GL     overcast clouds
# 5       12.91      KI          few clouds
# 6        8.03      RU     overcast clouds
# 7        5.64      RU          few clouds
# 8       14.74      KZ     overcast clouds
# 9        5.35      BR          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description" ]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini      TO -21.2000 -175.2000     76.50        73         100
# 1          Poopo      BO -18.3667  -66.9667     66.45         5           0
# 2       Beeville      US  28.4008  -97.7483     50.63        50         100
# 3       Bengkulu      ID  -3.8004  102.2655     74.19        90          98
# 4         Narsaq      GL  60.9167  -46.0500     26.82        81         100
# 5     Butaritari      KI   3.0707  172.7902     80.35        79          15
# 6       Cherskiy      RU  68.7500  161.3000    -13.59        98         100
# 7  Leningradskiy      RU  69.3833  178.4167    -24.61        97          13
# 8        Ushtobe      KZ  45.2514   77.9838     43.97        85         100
# 9        Urucara      BR  -2.5364  -57.7600    102.65        23          18
#
#    Wind Speed Weather Description
# 0        6.44     overcast clouds
# 1       14.58           clear sky
# 2        4.61     overcast clouds
# 3        5.06     overcast clouds
# 4        1.03     overcast clouds
# 5       12.91          few clouds
# 6        8.03     overcast clouds
# 7        5.64          few clouds
# 8       14.74     overcast clouds
# 9        5.35          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
